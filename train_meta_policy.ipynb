# %%
from pathlib import Path

import gym
import navstack_gym
import torch

import numpy as np
import matplotlib.pyplot as plt
import h5py

from gym.wrappers import TimeLimit, FrameStack
from algo.wrapper import ResizeObservation, TensorObservation

from pprint import pprint as p
from algo import utils
from algo.agent import make_DrQ_agent

# %%
################# Task Setting ####################
# reference ./conf/ 
TARGET = 'treasure_hunt_with_fixed_all'
EXPERIMENT_NAME = 'maintask_meta_fixed_all'

map_agent = 'subtask_map_fixed_room'
chest_agent = 'subtask_chest_fixed_room'
key_agent = 'subtask_key_fixed_room'
map_agent_path = utils.get_workspace_path(map_agent) / 'agent'
chest_agent_path = utils.get_workspace_path(chest_agent) / 'agent'
key_agent_path = utils.get_workspace_path(key_agent) / 'agent'

n_subtask = 3

cfg = utils.load_param('conf', 'train_config.yaml', [f'task={TARGET}', f'experiment_name={EXPERIMENT_NAME}'])

utils.create_workspace(cfg.experiment_name)
workspace_path = utils.get_workspace_path(cfg.experiment_name)

p(cfg)
env_mode = cfg.env_config.full
room_mode = cfg.room_config.hodoyoi

gpu = torch.cuda.current_device() if torch.cuda.is_available() else -1
# Out:
# set workspace: work/maintask_meta
# {'room_config': {'easy': {'scene_obstacle_count': 10, 'scene_obstacle_size': 0.7, 'scene_target_size': 0.2, 'scene_key_size': 0.2, 'scene_obstacle_zone_thresh': 1.5, 'scene_distance_key_placing': 0.7, 'scene_range_key_placing': 0.3, 'scene_room_length_max': 9, 'scene_room_wall_thickness': 0.05, 'scene_wall_threshold': 0.1}, 'crowded': {'scene_obstacle_count': 15, 'scene_obstacle_size': 0.6, 'scene_target_size': 0.2, 'scene_key_size': 0.2, 'scene_obstacle_zone_thresh': 1.5, 'scene_distance_key_placing': 0.7, 'scene_range_key_placing': 0.3, 'scene_room_length_max': 9, 'scene_room_wall_thickness': 0.05, 'scene_wall_threshold': 0.1}, 'hodoyoi': {'scene_obstacle_count': 13, 'scene_obstacle_size': 0.6, 'scene_target_size': 0.3, 'scene_key_size': 0.2, 'scene_obstacle_zone_thresh': 1.0, 'scene_distance_key_placing': 0.7, 'scene_range_key_placing': 0.3, 'scene_room_length_max': 9, 'scene_room_wall_thickness': 0.05, 'scene_wall_threshold': 0.2}}, 'env_config': {'zantei': {'map_size': 128, 'map_resolution': 0.1, 'map_unk_val': 50, 'map_pass_val': 0, 'map_obs_val': 100, 'path_exploration_count': 2500, 'path_planning_count': 7, 'allowable_goal_error_norm': 0.5, 'avoidance_size': 2, 'move_limit': 15, 'found_threshold': 0.7}, 'kairyo': {'map_size': 128, 'map_resolution': 0.1, 'spawn_extension': 0.5, 'path_exploration_count': 2500, 'path_planning_count': 7, 'avoidance_size': 3, 'move_limit': 20, 'movable_discount': 6, 'found_threshold': 0.6, 'map_obs_val': 100, 'map_pass_val': 0, 'map_unk_val': 50}, 'full': {'map_size': 150, 'map_resolution': 0.1, 'spawn_extension': 0.6, 'path_exploration_count': 2500, 'path_planning_count': 7, 'avoidance_size': 3, 'move_limit': 20, 'movable_discount': 6, 'found_threshold': 0.6, 'map_obs_val': 100, 'map_pass_val': 0, 'map_unk_val': 50}}, 'experiment_name': 'maintask_meta', 'env_id': 'VisibleTreasureHunt-v0', 'feature_dim': 50, 'hidden_dim': 1024, 'lr': 0.0001, 'image_pad': 4, 'gamma': 0.99, 'replay_start_size': 2000, 'batch_size': 256, 'update_interval': 2, 'capacity': 100000, 'n_episodes': 2000, 'eval_step': 10, 'set_seed': True, 'env_seed': 1234, 'change_room': False, 'change_pose': True, 'stack_num': 2, 'max_episode_steps': 50, 'observation_resize': 84}

# %%
env = gym.make(cfg.env_id, **env_mode)
env = ResizeObservation(env, cfg.observation_resize)
env = FrameStack(env, cfg.stack_num)
env = TensorObservation(env)
env = TimeLimit(env, max_episode_steps=cfg.max_episode_steps)

if cfg.set_seed:
    np.random.seed(cfg.env_seed)
    
obs = env.reset(**room_mode)
# Out:
# /home/tagokeniot/tmp/.venv/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# /home/tagokeniot/tmp/wrapper.py:30: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.as_tensor(observation, dtype=torch.float32)

# %%
subtasks = [None] * n_subtask

for i in range(n_subtask):
    subtasks[i] = make_DrQ_agent(
        experiment_name=cfg.experiment_name, 
        obs_space=env.observation_space, 
        action_space=env.action_space,
        feature_dim=cfg.feature_dim,
        hidden_dim=cfg.hidden_dim,
        lr=cfg.lr,
        image_pad=cfg.image_pad,
        gamma=cfg.gamma,
        replay_start_size=cfg.replay_start_size,
        capacity=cfg.capacity,
        gpu=gpu,
        batch_size=cfg.batch_size,
        update_interval=cfg.update_interval,
        is_persistent_buffer=False)
# Out:
# set workspace: work/maintask_meta
# set workspace: work/maintask_meta
# set workspace: work/maintask_meta

# %%
subtasks[0].load(str(map_agent_path))
subtasks[1].load(str(chest_agent_path))
subtasks[2].load(str(key_agent_path))

# %%
for s in subtasks:
    s.training = False

# %% [markdown]
# ## DQN Agent

# %%
import pfrl
qfunc = pfrl.q_functions.DuelingDQN(n_subtask, cfg.stack_num)

final_eps = 0.01
eval_eps = 0.001
final_exploration_frames = 5 * 10 ** 4

# %%
opt = pfrl.optimizers.RMSpropEpsInsideSqrt(
    qfunc.parameters(),
    lr=cfg.lr,
    alpha=0.95,
    momentum=0.0,
    eps=1e-2,
    centered=True,
)
rbuf = pfrl.replay_buffers.PersistentEpisodicReplayBuffer(f'{str(workspace_path)}/rbuf', cfg.capacity)
explorer = pfrl.explorers.LinearDecayEpsilonGreedy(
    1.0,
    final_eps,
    final_exploration_frames,
    lambda: np.random.randint(n_subtask),
)
phi = lambda x: np.asarray(x, dtype=np.float32) / 100

# %%
agent = pfrl.agents.DoubleDQN(
    qfunc,
    opt,
    rbuf,
    gpu=gpu,
    gamma=cfg.gamma,
    explorer=explorer,
    replay_start_size=cfg.replay_start_size,
    update_interval=cfg.update_interval,
    minibatch_size=cfg.batch_size,
    target_update_interval=5000,
    phi=phi
)

# %% [markdown]
# ## Train

# %%
result_filename = f'{str(workspace_path)}/result.hdf5'

with h5py.File(result_filename, 'a') as f:
    agent_statics_group = 'agent_statics'
    agent_statics_labels = [s[0] for s in agent.get_statistics()]
    for l in agent_statics_labels:
        f.create_dataset(f'{agent_statics_group}/{l}', shape=(cfg.n_episodes,))

    episode_rewards_group = 'episode_rewards'
    episode_rewards_labels = ['episode', 'total_reward']
    for l in episode_rewards_labels:
        f.create_dataset(f'{episode_rewards_group}/{l}', shape=(cfg.n_episodes,))

import datetime
start = datetime.datetime.now()
print(f'\n====================\nStart Training: {start}\n====================\n')
# Out:
# ====================
# Start Training: 2022-02-01 18:08:29.985541
# ====================

# %%
for i in range(cfg.n_episodes):
    obs = env.reset(is_generate_room=cfg.change_room, is_generate_pose=cfg.change_pose, **room_mode)
    R = 0  # return (sum of rewards)
    while True:
        # Uncomment to watch the behavior in a GUI window
        # env.render()
        select = agent.act(obs)

        ## select subtask
        sub = subtasks[select]
        action = sub.act(obs)

        obs, reward, done, _ = env.step(action)
        R += reward
        
        agent.observe(obs, reward, done, done)
        sub.observe(obs, reward, done, done)

        if done:
            break

    print('=============')
    print(f'episode: {i}, reward: {R}')
    print(f'statics: {agent.get_statistics()}')
    
    ## record result
    with h5py.File(result_filename, 'a') as f:
        f[episode_rewards_group]['episode'][i] = i+1
        f[episode_rewards_group]['total_reward'][i] = R
        for statics in agent.get_statistics():
            f[agent_statics_group][statics[0]][i] = statics[1]

print('Finished')
print(f'\n====================\nTraining Time: {datetime.datetime.now() - start}\n====================\n')

agent.save(f'{str(workspace_path)}/agent')
# Out:
# =============
# episode: 0, reward: 48.000000000000036
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 50), ('n_updates', 0), ('rlen', 50)]
# =============
# episode: 1, reward: 97.99999999999977
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 100), ('n_updates', 0), ('rlen', 100)]
# =============
# episode: 2, reward: 48.00000000000003
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 150), ('n_updates', 0), ('rlen', 150)]
# =============
# episode: 3, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 200), ('n_updates', 0), ('rlen', 200)]
# =============
# episode: 4, reward: 148.0000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 250), ('n_updates', 0), ('rlen', 250)]
# =============
# episode: 5, reward: 97.99999999999996
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 300), ('n_updates', 0), ('rlen', 300)]
# =============
# episode: 6, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 350), ('n_updates', 0), ('rlen', 350)]
# =============
# episode: 7, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 400), ('n_updates', 0), ('rlen', 400)]
# =============
# episode: 8, reward: 97.99999999999987
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 450), ('n_updates', 0), ('rlen', 450)]
# =============
# episode: 9, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 500), ('n_updates', 0), ('rlen', 500)]
# =============
# episode: 10, reward: 48.000000000000014
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 550), ('n_updates', 0), ('rlen', 550)]
# =============
# episode: 11, reward: 148.00000000000009
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 600), ('n_updates', 0), ('rlen', 600)]
# =============
# episode: 12, reward: 97.99999999999986
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 650), ('n_updates', 0), ('rlen', 650)]
# =============
# episode: 13, reward: 97.9999999999999
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 700), ('n_updates', 0), ('rlen', 700)]
# =============
# episode: 14, reward: 97.99999999999989
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 750), ('n_updates', 0), ('rlen', 750)]
# =============
# episode: 15, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 800), ('n_updates', 0), ('rlen', 800)]
# =============
# episode: 16, reward: 97.99999999999982
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 850), ('n_updates', 0), ('rlen', 850)]
# =============
# episode: 17, reward: 148.0
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 900), ('n_updates', 0), ('rlen', 900)]
# =============
# episode: 18, reward: 48.00000000000003
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 950), ('n_updates', 0), ('rlen', 950)]
# =============
# episode: 19, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1000), ('n_updates', 0), ('rlen', 1000)]
# =============
# episode: 20, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1050), ('n_updates', 0), ('rlen', 1050)]
# =============
# episode: 21, reward: 48.00000000000002
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1100), ('n_updates', 0), ('rlen', 1100)]
# =============
# episode: 22, reward: 48.000000000000036
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1150), ('n_updates', 0), ('rlen', 1150)]
# =============
# episode: 23, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1200), ('n_updates', 0), ('rlen', 1200)]
# =============
# episode: 24, reward: 97.99999999999993
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1250), ('n_updates', 0), ('rlen', 1250)]
# =============
# episode: 25, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1300), ('n_updates', 0), ('rlen', 1300)]
# =============
# episode: 26, reward: 97.99999999999999
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1350), ('n_updates', 0), ('rlen', 1350)]
# =============
# episode: 27, reward: 48.00000000000004
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1400), ('n_updates', 0), ('rlen', 1400)]
# =============
# episode: 28, reward: 48.00000000000003
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1450), ('n_updates', 0), ('rlen', 1450)]
# =============
# episode: 29, reward: 48.000000000000014
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1500), ('n_updates', 0), ('rlen', 1500)]
# =============
# episode: 30, reward: 97.99999999999986
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1550), ('n_updates', 0), ('rlen', 1550)]
# =============
# episode: 31, reward: 48.0
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1600), ('n_updates', 0), ('rlen', 1600)]
# =============
# episode: 32, reward: 148.00000000000003
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1650), ('n_updates', 0), ('rlen', 1650)]
# =============
# episode: 33, reward: 97.99999999999974
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1700), ('n_updates', 0), ('rlen', 1700)]
# =============
# episode: 34, reward: 97.99999999999977
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1750), ('n_updates', 0), ('rlen', 1750)]
# =============
# episode: 35, reward: 48.00000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1800), ('n_updates', 0), ('rlen', 1800)]
# =============
# episode: 36, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1850), ('n_updates', 0), ('rlen', 1850)]
# =============
# episode: 37, reward: 48.00000000000003
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1900), ('n_updates', 0), ('rlen', 1900)]
# =============
# episode: 38, reward: -2.000000000000001
# statics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1950), ('n_updates', 0), ('rlen', 1950)]
# =============
# episode: 39, reward: -2.000000000000001
# statics: [('average_q', 0.16330346), ('average_loss', 49.4764404296875), ('cumulative_steps', 2000), ('n_updates', 1), ('rlen', 2000)]
# /home/tagokeniot/tmp/.venv/lib/python3.8/site-packages/pfrl/optimizers/rmsprop_eps_inside_sqrt.py:44: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   square_avg.mul_(alpha).addcmul_(1 - alpha, grad, grad)
# =============
# episode: 40, reward: 48.00000000000003
# statics: [('average_q', 0.17526743), ('average_loss', 34.688764980492685), ('cumulative_steps', 2050), ('n_updates', 26), ('rlen', 2050)]
# =============
# episode: 41, reward: -2.000000000000001
# statics: [('average_q', 0.18551989), ('average_loss', 39.119288754521634), ('cumulative_steps', 2100), ('n_updates', 51), ('rlen', 2100)]
# =============
# episode: 42, reward: 48.000000000000036
# statics: [('average_q', 0.17880005), ('average_loss', 39.32541632377788), ('cumulative_steps', 2150), ('n_updates', 76), ('rlen', 2150)]
# =============
# episode: 43, reward: 97.99999999999997
# statics: [('average_q', 0.1758468), ('average_loss', 40.32349971607327), ('cumulative_steps', 2200), ('n_updates', 101), ('rlen', 2200)]
# =============
# episode: 44, reward: 48.000000000000014
# statics: [('average_q', 0.17595136), ('average_loss', 37.77058039620519), ('cumulative_steps', 2250), ('n_updates', 126), ('rlen', 2250)]
# =============
# episode: 45, reward: -2.000000000000001
# statics: [('average_q', 0.17961743), ('average_loss', 35.27226596355438), ('cumulative_steps', 2300), ('n_updates', 151), ('rlen', 2300)]
# =============
# episode: 46, reward: 48.000000000000014
# statics: [('average_q', 0.17281504), ('average_loss', 32.292788525298235), ('cumulative_steps', 2350), ('n_updates', 176), ('rlen', 2350)]
# =============
# episode: 47, reward: 48.000000000000036
# statics: [('average_q', 0.16625321), ('average_loss', 26.832274244055153), ('cumulative_steps', 2400), ('n_updates', 201), ('rlen', 2400)]
# =============
# episode: 48, reward: 48.00000000000002
# statics: [('average_q', 0.18372235), ('average_loss', 29.785609065815805), ('cumulative_steps', 2450), ('n_updates', 226), ('rlen', 2450)]
# =============
# episode: 49, reward: 97.99999999999987
# statics: [('average_q', 0.17448777), ('average_loss', 29.283421954214575), ('cumulative_steps', 2500), ('n_updates', 251), ('rlen', 2500)]
# =============
# episode: 50, reward: -2.000000000000001
# statics: [('average_q', 0.17625865), ('average_loss', 30.765524524524807), ('cumulative_steps', 2550), ('n_updates', 276), ('rlen', 2550)]
# =============
# episode: 51, reward: 48.00000000000003
# statics: [('average_q', 0.18421677), ('average_loss', 39.16945163346827), ('cumulative_steps', 2600), ('n_updates', 301), ('rlen', 2600)]
# =============
# episode: 52, reward: 97.99999999999987
# statics: [('average_q', 0.1784345), ('average_loss', 37.69087048642337), ('cumulative_steps', 2650), ('n_updates', 326), ('rlen', 2650)]
# =============
# episode: 53, reward: 48.0
# statics: [('average_q', 0.16913007), ('average_loss', 36.69511481709778), ('cumulative_steps', 2700), ('n_updates', 351), ('rlen', 2700)]
# =============
# episode: 54, reward: 48.00000000000003
# statics: [('average_q', 0.18155201), ('average_loss', 38.15029656410217), ('cumulative_steps', 2750), ('n_updates', 376), ('rlen', 2750)]
# =============
# episode: 55, reward: 97.99999999999987
# statics: [('average_q', 0.16897959), ('average_loss', 32.217239739894865), ('cumulative_steps', 2800), ('n_updates', 401), ('rlen', 2800)]
# =============
# episode: 56, reward: 48.000000000000014
# statics: [('average_q', 0.17710477), ('average_loss', 37.14654870089144), ('cumulative_steps', 2850), ('n_updates', 426), ('rlen', 2850)]
# =============
# episode: 57, reward: -2.000000000000001
# statics: [('average_q', 0.17907351), ('average_loss', 39.62433386910707), ('cumulative_steps', 2900), ('n_updates', 451), ('rlen', 2900)]
# =============
# episode: 58, reward: 147.99999999999997
# statics: [('average_q', 0.16576394), ('average_loss', 39.1511175717786), ('cumulative_steps', 2950), ('n_updates', 476), ('rlen', 2950)]
# =============
# episode: 59, reward: 97.99999999999996
# statics: [('average_q', 0.16921546), ('average_loss', 40.1314766003564), ('cumulative_steps', 3000), ('n_updates', 501), ('rlen', 3000)]
# =============
# episode: 60, reward: 98.0
# statics: [('average_q', 0.15298282), ('average_loss', 32.72783321261406), ('cumulative_steps', 3050), ('n_updates', 526), ('rlen', 3050)]
# =============
# episode: 61, reward: -2.000000000000001
# statics: [('average_q', 0.16427566), ('average_loss', 35.20947603844106), ('cumulative_steps', 3100), ('n_updates', 551), ('rlen', 3100)]
# =============
# episode: 62, reward: 48.00000000000001
# statics: [('average_q', 0.1727259), ('average_loss', 37.65884840428829), ('cumulative_steps', 3150), ('n_updates', 576), ('rlen', 3150)]
# =============
# episode: 63, reward: 48.000000000000036
# statics: [('average_q', 0.15458351), ('average_loss', 35.667315874546766), ('cumulative_steps', 3200), ('n_updates', 601), ('rlen', 3200)]
# =============
# episode: 64, reward: 97.99999999999996
# statics: [('average_q', 0.15857595), ('average_loss', 37.64582597263157), ('cumulative_steps', 3250), ('n_updates', 626), ('rlen', 3250)]
# =============
# episode: 65, reward: -2.000000000000001
# statics: [('average_q', 0.16963597), ('average_loss', 35.16937778919935), ('cumulative_steps', 3300), ('n_updates', 651), ('rlen', 3300)]
# =============
# episode: 66, reward: 48.00000000000003
# statics: [('average_q', 0.16556597), ('average_loss', 33.21394358664751), ('cumulative_steps', 3350), ('n_updates', 676), ('rlen', 3350)]
# =============
# episode: 67, reward: -2.000000000000001
# statics: [('average_q', 0.18201348), ('average_loss', 39.64102214977145), ('cumulative_steps', 3400), ('n_updates', 701), ('rlen', 3400)]
# =============
# episode: 68, reward: -2.000000000000001
# statics: [('average_q', 0.17430887), ('average_loss', 41.60045496411622), ('cumulative_steps', 3450), ('n_updates', 726), ('rlen', 3450)]
# =============
# episode: 69, reward: -2.000000000000001
# statics: [('average_q', 0.18489332), ('average_loss', 42.57515610225499), ('cumulative_steps', 3500), ('n_updates', 751), ('rlen', 3500)]
# =============
# episode: 70, reward: 48.000000000000014
# statics: [('average_q', 0.17273133), ('average_loss', 42.572845419049266), ('cumulative_steps', 3550), ('n_updates', 776), ('rlen', 3550)]
# =============
# episode: 71, reward: 97.99999999999991
# statics: [('average_q', 0.17315148), ('average_loss', 42.57985819205642), ('cumulative_steps', 3600), ('n_updates', 801), ('rlen', 3600)]
# =============
# episode: 72, reward: 48.00000000000003
# statics: [('average_q', 0.16747436), ('average_loss', 41.60293607503176), ('cumulative_steps', 3650), ('n_updates', 826), ('rlen', 3650)]
# =============
# episode: 73, reward: -2.000000000000001
# statics: [('average_q', 0.15804869), ('average_loss', 40.610775084793566), ('cumulative_steps', 3700), ('n_updates', 851), ('rlen', 3700)]
# =============
# episode: 74, reward: -2.000000000000001
# statics: [('average_q', 0.15956591), ('average_loss', 37.13913130223751), ('cumulative_steps', 3750), ('n_updates', 876), ('rlen', 3750)]
# =============
# episode: 75, reward: 48.0
# statics: [('average_q', 0.17293005), ('average_loss', 34.16072410829365), ('cumulative_steps', 3800), ('n_updates', 901), ('rlen', 3800)]
# =============
# episode: 76, reward: -2.000000000000001
# statics: [('average_q', 0.16412798), ('average_loss', 35.13447217985988), ('cumulative_steps', 3850), ('n_updates', 926), ('rlen', 3850)]
# =============
# episode: 77, reward: -2.000000000000001
# statics: [('average_q', 0.16544421), ('average_loss', 34.64961103092879), ('cumulative_steps', 3900), ('n_updates', 951), ('rlen', 3900)]
# =============
# episode: 78, reward: -2.000000000000001
# statics: [('average_q', 0.17787775), ('average_loss', 37.61344896886498), ('cumulative_steps', 3950), ('n_updates', 976), ('rlen', 3950)]
# =============
# episode: 79, reward: 98.0
# statics: [('average_q', 0.16821195), ('average_loss', 34.65740704845637), ('cumulative_steps', 4000), ('n_updates', 1001), ('rlen', 4000)]
# =============
# episode: 80, reward: -2.000000000000001
# statics: [('average_q', 0.16035588), ('average_loss', 31.68723434332758), ('cumulative_steps', 4050), ('n_updates', 1026), ('rlen', 4050)]
# =============
# episode: 81, reward: 48.000000000000014
# statics: [('average_q', 0.15885116), ('average_loss', 30.692680061012506), ('cumulative_steps', 4100), ('n_updates', 1051), ('rlen', 4100)]
# =============
# episode: 82, reward: -2.000000000000001
# statics: [('average_q', 0.17197824), ('average_loss', 32.17398253142834), ('cumulative_steps', 4150), ('n_updates', 1076), ('rlen', 4150)]
# =============
# episode: 83, reward: -2.000000000000001
# statics: [('average_q', 0.15664868), ('average_loss', 35.12362815536559), ('cumulative_steps', 4200), ('n_updates', 1101), ('rlen', 4200)]
# =============
# episode: 84, reward: 48.0
# statics: [('average_q', 0.16625369), ('average_loss', 39.56417730361223), ('cumulative_steps', 4250), ('n_updates', 1126), ('rlen', 4250)]
# =============
# episode: 85, reward: -2.000000000000001
# statics: [('average_q', 0.18299347), ('average_loss', 42.02712451413274), ('cumulative_steps', 4300), ('n_updates', 1151), ('rlen', 4300)]
# =============
# episode: 86, reward: 48.00000000000002
# statics: [('average_q', 0.17728141), ('average_loss', 39.547656910270454), ('cumulative_steps', 4350), ('n_updates', 1176), ('rlen', 4350)]
# =============
# episode: 87, reward: 48.00000000000003
# statics: [('average_q', 0.17164469), ('average_loss', 41.022188463360074), ('cumulative_steps', 4400), ('n_updates', 1201), ('rlen', 4400)]
# =============
# episode: 88, reward: 48.00000000000004
# statics: [('average_q', 0.1701076), ('average_loss', 37.575326885059475), ('cumulative_steps', 4450), ('n_updates', 1226), ('rlen', 4450)]
# =============
# episode: 89, reward: -2.000000000000001
# statics: [('average_q', 0.17940763), ('average_loss', 36.58032575450838), ('cumulative_steps', 4500), ('n_updates', 1251), ('rlen', 4500)]
# =============
# episode: 90, reward: 97.99999999999991
# statics: [('average_q', 0.16037282), ('average_loss', 35.60385931748897), ('cumulative_steps', 4550), ('n_updates', 1276), ('rlen', 4550)]
# =============
# episode: 91, reward: -2.000000000000001
# statics: [('average_q', 0.16660778), ('average_loss', 29.200746977515518), ('cumulative_steps', 4600), ('n_updates', 1301), ('rlen', 4600)]
# =============
# episode: 92, reward: 48.00000000000003
# statics: [('average_q', 0.15198193), ('average_loss', 29.69642778661102), ('cumulative_steps', 4650), ('n_updates', 1326), ('rlen', 4650)]
# =============
# episode: 93, reward: 48.000000000000014
# statics: [('average_q', 0.16519937), ('average_loss', 27.730238788239657), ('cumulative_steps', 4700), ('n_updates', 1351), ('rlen', 4700)]
# =============
# episode: 94, reward: -2.000000000000001
# statics: [('average_q', 0.17636734), ('average_loss', 32.15140727877617), ('cumulative_steps', 4750), ('n_updates', 1376), ('rlen', 4750)]
# =============
# episode: 95, reward: -2.000000000000001
# statics: [('average_q', 0.17929922), ('average_loss', 36.080131460800764), ('cumulative_steps', 4800), ('n_updates', 1401), ('rlen', 4800)]
# =============
# episode: 96, reward: 48.00000000000003
# statics: [('average_q', 0.19243416), ('average_loss', 41.993078438937665), ('cumulative_steps', 4850), ('n_updates', 1426), ('rlen', 4850)]
# =============
# episode: 97, reward: 48.00000000000003
# statics: [('average_q', 0.16331698), ('average_loss', 40.025128819793466), ('cumulative_steps', 4900), ('n_updates', 1451), ('rlen', 4900)]
# =============
# episode: 98, reward: 48.000000000000014
# statics: [('average_q', 0.1648107), ('average_loss', 40.52300469852984), ('cumulative_steps', 4950), ('n_updates', 1476), ('rlen', 4950)]
# =============
# episode: 99, reward: 48.000000000000014
# statics: [('average_q', 0.16379504), ('average_loss', 39.0592109028995), ('cumulative_steps', 5000), ('n_updates', 1501), ('rlen', 5000)]
# =============
# episode: 100, reward: 48.00000000000001
# statics: [('average_q', 0.16332068), ('average_loss', 36.59085243612528), ('cumulative_steps', 5050), ('n_updates', 1526), ('rlen', 5050)]
# =============
# episode: 101, reward: -2.000000000000001
# statics: [('average_q', 0.15927374), ('average_loss', 39.04910947844386), ('cumulative_steps', 5100), ('n_updates', 1551), ('rlen', 5100)]
# =============
# episode: 102, reward: 48.0
# statics: [('average_q', 0.16605665), ('average_loss', 36.08088573172689), ('cumulative_steps', 5150), ('n_updates', 1576), ('rlen', 5150)]
# =============
# episode: 103, reward: -2.000000000000001
# statics: [('average_q', 0.16387811), ('average_loss', 36.57231772378087), ('cumulative_steps', 5200), ('n_updates', 1601), ('rlen', 5200)]
# =============
# episode: 104, reward: 48.000000000000014
# statics: [('average_q', 0.16030654), ('average_loss', 35.078788200244304), ('cumulative_steps', 5250), ('n_updates', 1626), ('rlen', 5250)]
# =============
# episode: 105, reward: 97.99999999999999
# statics: [('average_q', 0.15304136), ('average_loss', 34.09152138225734), ('cumulative_steps', 5300), ('n_updates', 1651), ('rlen', 5300)]
# =============
# episode: 106, reward: -2.000000000000001
# statics: [('average_q', 0.16220035), ('average_loss', 34.597119872793556), ('cumulative_steps', 5350), ('n_updates', 1676), ('rlen', 5350)]
# =============
# episode: 107, reward: 48.00000000000003
# statics: [('average_q', 0.16472535), ('average_loss', 35.07839463621378), ('cumulative_steps', 5400), ('n_updates', 1701), ('rlen', 5400)]
# =============
# episode: 108, reward: 48.000000000000014
# statics: [('average_q', 0.14842848), ('average_loss', 30.175857392586767), ('cumulative_steps', 5450), ('n_updates', 1726), ('rlen', 5450)]
# =============
# episode: 109, reward: 48.00000000000001
# statics: [('average_q', 0.15532419), ('average_loss', 31.167504373304546), ('cumulative_steps', 5500), ('n_updates', 1751), ('rlen', 5500)]
# =============
# episode: 110, reward: 48.000000000000014
# statics: [('average_q', 0.14854892), ('average_loss', 32.14493709508329), ('cumulative_steps', 5550), ('n_updates', 1776), ('rlen', 5550)]
# =============
# episode: 111, reward: -2.000000000000001
# statics: [('average_q', 0.16150156), ('average_loss', 30.673041570968927), ('cumulative_steps', 5600), ('n_updates', 1801), ('rlen', 5600)]
# =============
# episode: 112, reward: -2.000000000000001
# statics: [('average_q', 0.16264749), ('average_loss', 39.03473157957196), ('cumulative_steps', 5650), ('n_updates', 1826), ('rlen', 5650)]
# =============
# episode: 113, reward: 48.00000000000003
# statics: [('average_q', 0.1690112), ('average_loss', 38.04596562735736), ('cumulative_steps', 5700), ('n_updates', 1851), ('rlen', 5700)]
# =============
# episode: 114, reward: 48.00000000000003
# statics: [('average_q', 0.15874778), ('average_loss', 34.60492012731731), ('cumulative_steps', 5750), ('n_updates', 1876), ('rlen', 5750)]
# =============
# episode: 115, reward: 48.0
# statics: [('average_q', 0.15834399), ('average_loss', 38.05779328174889), ('cumulative_steps', 5800), ('n_updates', 1901), ('rlen', 5800)]
# =============
# episode: 116, reward: 48.0
# statics: [('average_q', 0.15990736), ('average_loss', 31.160368966907264), ('cumulative_steps', 5850), ('n_updates', 1926), ('rlen', 5850)]
# =============
# episode: 117, reward: -2.000000000000001
# statics: [('average_q', 0.15442778), ('average_loss', 31.644445956349372), ('cumulative_steps', 5900), ('n_updates', 1951), ('rlen', 5900)]
# =============
# episode: 118, reward: 97.9999999999998
# statics: [('average_q', 0.14802222), ('average_loss', 27.69207615375519), ('cumulative_steps', 5950), ('n_updates', 1976), ('rlen', 5950)]
# =============
# episode: 119, reward: 48.0
# statics: [('average_q', 0.15469448), ('average_loss', 25.225361720994115), ('cumulative_steps', 6000), ('n_updates', 2001), ('rlen', 6000)]
# =============
# episode: 120, reward: 48.000000000000014
# statics: [('average_q', 0.15339975), ('average_loss', 26.217462172359227), ('cumulative_steps', 6050), ('n_updates', 2026), ('rlen', 6050)]
# =============
# episode: 121, reward: 98.00000000000001
# statics: [('average_q', 0.15584229), ('average_loss', 27.70473759777844), ('cumulative_steps', 6100), ('n_updates', 2051), ('rlen', 6100)]
# =============
# episode: 122, reward: 97.99999999999994
# statics: [('average_q', 0.17270464), ('average_loss', 36.08357582062483), ('cumulative_steps', 6150), ('n_updates', 2076), ('rlen', 6150)]
# =============
# episode: 123, reward: -2.000000000000001
# statics: [('average_q', 0.16602564), ('average_loss', 37.05625238902867), ('cumulative_steps', 6200), ('n_updates', 2101), ('rlen', 6200)]
# =============
# episode: 124, reward: 48.00000000000001
# statics: [('average_q', 0.16356461), ('average_loss', 35.58540126547217), ('cumulative_steps', 6250), ('n_updates', 2126), ('rlen', 6250)]
# =============
# episode: 125, reward: 48.0
# statics: [('average_q', 0.15294228), ('average_loss', 34.604015484526755), ('cumulative_steps', 6300), ('n_updates', 2151), ('rlen', 6300)]
# =============
# episode: 126, reward: -2.000000000000001
# statics: [('average_q', 0.16590549), ('average_loss', 30.65247682608664), ('cumulative_steps', 6350), ('n_updates', 2176), ('rlen', 6350)]
# =============
# episode: 127, reward: 48.000000000000036
# statics: [('average_q', 0.15586774), ('average_loss', 27.22026999555528), ('cumulative_steps', 6400), ('n_updates', 2201), ('rlen', 6400)]
# =============
# episode: 128, reward: -2.000000000000001
# statics: [('average_q', 0.16801733), ('average_loss', 31.636781383007765), ('cumulative_steps', 6450), ('n_updates', 2226), ('rlen', 6450)]
# =============
# episode: 129, reward: -2.000000000000001
# statics: [('average_q', 0.15663263), ('average_loss', 32.10903637681157), ('cumulative_steps', 6500), ('n_updates', 2251), ('rlen', 6500)]
# =============
# episode: 130, reward: -2.000000000000001
# statics: [('average_q', 0.14851935), ('average_loss', 29.66509685587138), ('cumulative_steps', 6550), ('n_updates', 2276), ('rlen', 6550)]
# =============
# episode: 131, reward: 147.99999999999986
# statics: [('average_q', 0.14957502), ('average_loss', 30.15811274666339), ('cumulative_steps', 6600), ('n_updates', 2301), ('rlen', 6600)]
# =============
# episode: 132, reward: 48.000000000000036
# statics: [('average_q', 0.15204966), ('average_loss', 26.22688621442765), ('cumulative_steps', 6650), ('n_updates', 2326), ('rlen', 6650)]
# =============
# episode: 133, reward: 97.99999999999997
# statics: [('average_q', 0.15791778), ('average_loss', 25.751756265312434), ('cumulative_steps', 6700), ('n_updates', 2351), ('rlen', 6700)]
# =============
# episode: 134, reward: 48.00000000000002
# statics: [('average_q', 0.1627934), ('average_loss', 28.68991069663316), ('cumulative_steps', 6750), ('n_updates', 2376), ('rlen', 6750)]
# =============
# episode: 135, reward: -2.000000000000001
# statics: [('average_q', 0.14016505), ('average_loss', 28.199150449857115), ('cumulative_steps', 6800), ('n_updates', 2401), ('rlen', 6800)]
# =============
# episode: 136, reward: 48.00000000000003
# statics: [('average_q', 0.16920532), ('average_loss', 31.638105279132724), ('cumulative_steps', 6850), ('n_updates', 2426), ('rlen', 6850)]
# =============
# episode: 137, reward: 48.00000000000001
# statics: [('average_q', 0.15198646), ('average_loss', 30.160194109790027), ('cumulative_steps', 6900), ('n_updates', 2451), ('rlen', 6900)]
# =============
# episode: 138, reward: 97.99999999999991
# statics: [('average_q', 0.1455883), ('average_loss', 27.704639847055077), ('cumulative_steps', 6950), ('n_updates', 2476), ('rlen', 6950)]
# =============
# episode: 139, reward: -2.000000000000001
# statics: [('average_q', 0.16208856), ('average_loss', 29.183129800520838), ('cumulative_steps', 7000), ('n_updates', 2501), ('rlen', 7000)]
# =============
# episode: 140, reward: 48.00000000000001
# statics: [('average_q', 0.15540472), ('average_loss', 27.219419389031827), ('cumulative_steps', 7050), ('n_updates', 2526), ('rlen', 7050)]
# =============
# episode: 141, reward: 48.00000000000001
# statics: [('average_q', 0.15119511), ('average_loss', 29.178878348320723), ('cumulative_steps', 7100), ('n_updates', 2551), ('rlen', 7100)]
# =============
# episode: 142, reward: -2.000000000000001
# statics: [('average_q', 0.13972668), ('average_loss', 26.720848737582564), ('cumulative_steps', 7150), ('n_updates', 2576), ('rlen', 7150)]
# =============
# episode: 143, reward: 48.00000000000001
# statics: [('average_q', 0.1540518), ('average_loss', 27.688430013135076), ('cumulative_steps', 7200), ('n_updates', 2601), ('rlen', 7200)]
# =============
# episode: 144, reward: 48.00000000000003
# statics: [('average_q', 0.16942221), ('average_loss', 31.609182803556322), ('cumulative_steps', 7250), ('n_updates', 2626), ('rlen', 7250)]
# =============
# episode: 145, reward: 48.00000000000002
# statics: [('average_q', 0.15535101), ('average_loss', 28.160862212441863), ('cumulative_steps', 7300), ('n_updates', 2651), ('rlen', 7300)]
# =============
# episode: 146, reward: 48.00000000000001
# statics: [('average_q', 0.16039582), ('average_loss', 33.075359069667755), ('cumulative_steps', 7350), ('n_updates', 2676), ('rlen', 7350)]
# =============
# episode: 147, reward: 48.00000000000002
# statics: [('average_q', 0.16932707), ('average_loss', 34.09074180852622), ('cumulative_steps', 7400), ('n_updates', 2701), ('rlen', 7400)]
# =============
# episode: 148, reward: 48.00000000000002
# statics: [('average_q', 0.15323617), ('average_loss', 29.19154296334833), ('cumulative_steps', 7450), ('n_updates', 2726), ('rlen', 7450)]
# =============
# episode: 149, reward: 48.000000000000036
# statics: [('average_q', 0.14869986), ('average_loss', 30.668773517385127), ('cumulative_steps', 7500), ('n_updates', 2751), ('rlen', 7500)]
# =============
# episode: 150, reward: -2.000000000000001
# statics: [('average_q', 0.15010723), ('average_loss', 30.67318192861974), ('cumulative_steps', 7550), ('n_updates', 2776), ('rlen', 7550)]
# =============
# episode: 151, reward: 48.00000000000001
# statics: [('average_q', 0.16452096), ('average_loss', 30.150105005651714), ('cumulative_steps', 7600), ('n_updates', 2801), ('rlen', 7600)]
# =============
# episode: 152, reward: -2.000000000000001
# statics: [('average_q', 0.16544582), ('average_loss', 33.103508213311436), ('cumulative_steps', 7650), ('n_updates', 2826), ('rlen', 7650)]
# =============
# episode: 153, reward: 97.99999999999986
# statics: [('average_q', 0.14824757), ('average_loss', 35.08253840520978), ('cumulative_steps', 7700), ('n_updates', 2851), ('rlen', 7700)]
# =============
# episode: 154, reward: -2.000000000000001
# statics: [('average_q', 0.15859243), ('average_loss', 32.61352734975517), ('cumulative_steps', 7750), ('n_updates', 2876), ('rlen', 7750)]
# =============
# episode: 155, reward: 48.00000000000003
# statics: [('average_q', 0.14865637), ('average_loss', 31.15032875239849), ('cumulative_steps', 7800), ('n_updates', 2901), ('rlen', 7800)]
# =============
# episode: 156, reward: 48.0
# statics: [('average_q', 0.14656666), ('average_loss', 25.730193640179934), ('cumulative_steps', 7850), ('n_updates', 2926), ('rlen', 7850)]
# =============
# episode: 157, reward: 48.000000000000036
# statics: [('average_q', 0.17228748), ('average_loss', 29.66411217469722), ('cumulative_steps', 7900), ('n_updates', 2951), ('rlen', 7900)]
# =============
# episode: 158, reward: -2.000000000000001
# statics: [('average_q', 0.15194309), ('average_loss', 28.69107029940933), ('cumulative_steps', 7950), ('n_updates', 2976), ('rlen', 7950)]
# =============
# episode: 159, reward: 48.000000000000014
# statics: [('average_q', 0.14628279), ('average_loss', 27.696055477298795), ('cumulative_steps', 8000), ('n_updates', 3001), ('rlen', 8000)]
# =============
# episode: 160, reward: -2.000000000000001
# statics: [('average_q', 0.1573185), ('average_loss', 33.1002436131984), ('cumulative_steps', 8050), ('n_updates', 3026), ('rlen', 8050)]
# =============
# episode: 161, reward: -2.000000000000001
# statics: [('average_q', 0.150245), ('average_loss', 28.17988114774227), ('cumulative_steps', 8100), ('n_updates', 3051), ('rlen', 8100)]
# =============
# episode: 162, reward: -2.000000000000001
# statics: [('average_q', 0.15018176), ('average_loss', 30.1455510943383), ('cumulative_steps', 8150), ('n_updates', 3076), ('rlen', 8150)]
# =============
# episode: 163, reward: -2.000000000000001
# statics: [('average_q', 0.16730762), ('average_loss', 33.0960930275172), ('cumulative_steps', 8200), ('n_updates', 3101), ('rlen', 8200)]
# =============
# episode: 164, reward: 97.99999999999991
# statics: [('average_q', 0.14140667), ('average_loss', 28.178897229880093), ('cumulative_steps', 8250), ('n_updates', 3126), ('rlen', 8250)]
# =============
# episode: 165, reward: 48.000000000000014
# statics: [('average_q', 0.15017633), ('average_loss', 25.220714505761862), ('cumulative_steps', 8300), ('n_updates', 3151), ('rlen', 8300)]
# =============
# episode: 166, reward: 48.000000000000014
# statics: [('average_q', 0.15916745), ('average_loss', 26.704155434444548), ('cumulative_steps', 8350), ('n_updates', 3176), ('rlen', 8350)]
# =============
# episode: 167, reward: 48.00000000000001
# statics: [('average_q', 0.15496945), ('average_loss', 23.271808020025492), ('cumulative_steps', 8400), ('n_updates', 3201), ('rlen', 8400)]
# =============
# episode: 168, reward: 48.000000000000036
# statics: [('average_q', 0.14901632), ('average_loss', 28.191193221956492), ('cumulative_steps', 8450), ('n_updates', 3226), ('rlen', 8450)]
# =============
# episode: 169, reward: 97.99999999999987
# statics: [('average_q', 0.1447848), ('average_loss', 30.65864922955632), ('cumulative_steps', 8500), ('n_updates', 3251), ('rlen', 8500)]
# =============
# episode: 170, reward: 97.99999999999991
# statics: [('average_q', 0.15457985), ('average_loss', 30.641797876358034), ('cumulative_steps', 8550), ('n_updates', 3276), ('rlen', 8550)]
# =============
# episode: 171, reward: 48.00000000000001
# statics: [('average_q', 0.15728003), ('average_loss', 31.622521535009145), ('cumulative_steps', 8600), ('n_updates', 3301), ('rlen', 8600)]
# =============
# episode: 172, reward: 97.99999999999996
# statics: [('average_q', 0.1608854), ('average_loss', 29.15410584114492), ('cumulative_steps', 8650), ('n_updates', 3326), ('rlen', 8650)]
# =============
# episode: 173, reward: 97.99999999999989
# statics: [('average_q', 0.16374952), ('average_loss', 28.651335480064155), ('cumulative_steps', 8700), ('n_updates', 3351), ('rlen', 8700)]
# =============
# episode: 174, reward: -2.000000000000001
# statics: [('average_q', 0.1585657), ('average_loss', 30.152926318719985), ('cumulative_steps', 8750), ('n_updates', 3376), ('rlen', 8750)]
# =============
# episode: 175, reward: 48.00000000000002
# statics: [('average_q', 0.15631367), ('average_loss', 31.118912772387265), ('cumulative_steps', 8800), ('n_updates', 3401), ('rlen', 8800)]
# =============
# episode: 176, reward: 48.00000000000002
# statics: [('average_q', 0.16316763), ('average_loss', 33.58405101291835), ('cumulative_steps', 8850), ('n_updates', 3426), ('rlen', 8850)]
# =============
# episode: 177, reward: -2.000000000000001
# statics: [('average_q', 0.14290906), ('average_loss', 34.579758376181125), ('cumulative_steps', 8900), ('n_updates', 3451), ('rlen', 8900)]
# =============
# episode: 178, reward: 48.00000000000003
# statics: [('average_q', 0.1638367), ('average_loss', 33.07908014059067), ('cumulative_steps', 8950), ('n_updates', 3476), ('rlen', 8950)]
# =============
# episode: 179, reward: 48.000000000000036
# statics: [('average_q', 0.16318253), ('average_loss', 33.10224470473826), ('cumulative_steps', 9000), ('n_updates', 3501), ('rlen', 9000)]
# =============
# episode: 180, reward: -2.000000000000001
# statics: [('average_q', 0.15591294), ('average_loss', 30.150333044454456), ('cumulative_steps', 9050), ('n_updates', 3526), ('rlen', 9050)]
# =============
# episode: 181, reward: 148.00000000000017
# statics: [('average_q', 0.15633689), ('average_loss', 28.665387726798652), ('cumulative_steps', 9100), ('n_updates', 3551), ('rlen', 9100)]
# =============
# episode: 182, reward: -2.000000000000001
# statics: [('average_q', 0.15794583), ('average_loss', 29.174590170606972), ('cumulative_steps', 9150), ('n_updates', 3576), ('rlen', 9150)]
# =============
# episode: 183, reward: 97.99999999999999
# statics: [('average_q', 0.17162201), ('average_loss', 29.66924955487251), ('cumulative_steps', 9200), ('n_updates', 3601), ('rlen', 9200)]
# =============
# episode: 184, reward: -2.000000000000001
# statics: [('average_q', 0.16856854), ('average_loss', 30.167174853682518), ('cumulative_steps', 9250), ('n_updates', 3626), ('rlen', 9250)]
# =============
# episode: 185, reward: 97.9999999999999
# statics: [('average_q', 0.15029266), ('average_loss', 28.699582818523048), ('cumulative_steps', 9300), ('n_updates', 3651), ('rlen', 9300)]
# =============
# episode: 186, reward: -2.000000000000001
# statics: [('average_q', 0.14076199), ('average_loss', 26.234545949175953), ('cumulative_steps', 9350), ('n_updates', 3676), ('rlen', 9350)]
# =============
# episode: 187, reward: 48.0
# statics: [('average_q', 0.16137229), ('average_loss', 25.235079313218595), ('cumulative_steps', 9400), ('n_updates', 3701), ('rlen', 9400)]
# =============
# episode: 188, reward: 98.00000000000001
# statics: [('average_q', 0.16774674), ('average_loss', 29.16228201456368), ('cumulative_steps', 9450), ('n_updates', 3726), ('rlen', 9450)]
# =============
# episode: 189, reward: -2.000000000000001
# statics: [('average_q', 0.16712674), ('average_loss', 34.06902704402805), ('cumulative_steps', 9500), ('n_updates', 3751), ('rlen', 9500)]
# =============
# episode: 190, reward: -2.000000000000001
# statics: [('average_q', 0.16020851), ('average_loss', 36.03573548406362), ('cumulative_steps', 9550), ('n_updates', 3776), ('rlen', 9550)]
# =============
# episode: 191, reward: -2.000000000000001
# statics: [('average_q', 0.15792078), ('average_loss', 36.042148144692185), ('cumulative_steps', 9600), ('n_updates', 3801), ('rlen', 9600)]
# =============
# episode: 192, reward: -2.000000000000001
# statics: [('average_q', 0.1550488), ('average_loss', 31.62187724895775), ('cumulative_steps', 9650), ('n_updates', 3826), ('rlen', 9650)]
# =============
# episode: 193, reward: 48.000000000000014
# statics: [('average_q', 0.15023942), ('average_loss', 28.676205277815463), ('cumulative_steps', 9700), ('n_updates', 3851), ('rlen', 9700)]
# =============
# episode: 194, reward: 97.99999999999999
# statics: [('average_q', 0.15986243), ('average_loss', 28.181993956640362), ('cumulative_steps', 9750), ('n_updates', 3876), ('rlen', 9750)]
# =============
# episode: 195, reward: -2.000000000000001
# statics: [('average_q', 0.16965875), ('average_loss', 30.114423312693834), ('cumulative_steps', 9800), ('n_updates', 3901), ('rlen', 9800)]
# =============
# episode: 196, reward: -2.000000000000001
# statics: [('average_q', 0.16065723), ('average_loss', 30.615323064178227), ('cumulative_steps', 9850), ('n_updates', 3926), ('rlen', 9850)]
# =============
# episode: 197, reward: -2.000000000000001
# statics: [('average_q', 0.15837298), ('average_loss', 32.58642440743744), ('cumulative_steps', 9900), ('n_updates', 3951), ('rlen', 9900)]
# =============
# episode: 198, reward: 97.99999999999997
# statics: [('average_q', 0.15553842), ('average_loss', 33.076415159106254), ('cumulative_steps', 9950), ('n_updates', 3976), ('rlen', 9950)]
# =============
# episode: 199, reward: 98.00000000000003
# statics: [('average_q', 0.14706345), ('average_loss', 32.630556221455336), ('cumulative_steps', 10000), ('n_updates', 4001), ('rlen', 10000)]
# =============
# episode: 200, reward: -2.000000000000001
# statics: [('average_q', 0.18874152), ('average_loss', 31.6562899658829), ('cumulative_steps', 10050), ('n_updates', 4026), ('rlen', 10050)]
# =============
# episode: 201, reward: -2.000000000000001
# statics: [('average_q', 0.19216648), ('average_loss', 27.71559810101986), ('cumulative_steps', 10100), ('n_updates', 4051), ('rlen', 10100)]
# =============
# episode: 202, reward: 98.0
# statics: [('average_q', 0.20404892), ('average_loss', 25.760384378656745), ('cumulative_steps', 10150), ('n_updates', 4076), ('rlen', 10150)]
# =============
# episode: 203, reward: 97.99999999999997
# statics: [('average_q', 0.1981396), ('average_loss', 22.310507224276662), ('cumulative_steps', 10200), ('n_updates', 4101), ('rlen', 10200)]
# =============
# episode: 204, reward: 98.0
# statics: [('average_q', 0.19969974), ('average_loss', 22.8042988575995), ('cumulative_steps', 10250), ('n_updates', 4126), ('rlen', 10250)]
# =============
# episode: 205, reward: 48.000000000000036
# statics: [('average_q', 0.21028873), ('average_loss', 28.710795931592585), ('cumulative_steps', 10300), ('n_updates', 4151), ('rlen', 10300)]
# =============
# episode: 206, reward: 48.000000000000036
# statics: [('average_q', 0.20837124), ('average_loss', 32.15707452893257), ('cumulative_steps', 10350), ('n_updates', 4176), ('rlen', 10350)]
# =============
# episode: 207, reward: -2.000000000000001
# statics: [('average_q', 0.19819012), ('average_loss', 33.64147385083139), ('cumulative_steps', 10400), ('n_updates', 4201), ('rlen', 10400)]
# =============
# episode: 208, reward: 148.00000000000009
# statics: [('average_q', 0.2086617), ('average_loss', 38.54859375596047), ('cumulative_steps', 10450), ('n_updates', 4226), ('rlen', 10450)]
# =============
# episode: 209, reward: 48.00000000000001
# statics: [('average_q', 0.20194048), ('average_loss', 34.124635373204946), ('cumulative_steps', 10500), ('n_updates', 4251), ('rlen', 10500)]
# =============
# episode: 210, reward: -2.000000000000001
# statics: [('average_q', 0.20161685), ('average_loss', 35.12353389762342), ('cumulative_steps', 10550), ('n_updates', 4276), ('rlen', 10550)]
# =============
# episode: 211, reward: 48.00000000000002
# statics: [('average_q', 0.19269104), ('average_loss', 33.15544298775494), ('cumulative_steps', 10600), ('n_updates', 4301), ('rlen', 10600)]
# =============
# episode: 212, reward: -2.000000000000001
# statics: [('average_q', 0.20646577), ('average_loss', 30.194123513102532), ('cumulative_steps', 10650), ('n_updates', 4326), ('rlen', 10650)]
# =============
# episode: 213, reward: 97.99999999999999
# statics: [('average_q', 0.20225045), ('average_loss', 31.17084549367428), ('cumulative_steps', 10700), ('n_updates', 4351), ('rlen', 10700)]
# =============
# episode: 214, reward: 97.99999999999999
# statics: [('average_q', 0.20227267), ('average_loss', 26.723137613087893), ('cumulative_steps', 10750), ('n_updates', 4376), ('rlen', 10750)]
# =============
# episode: 215, reward: 48.00000000000001
# statics: [('average_q', 0.1965926), ('average_loss', 28.67853039711714), ('cumulative_steps', 10800), ('n_updates', 4401), ('rlen', 10800)]
# =============
# episode: 216, reward: -2.000000000000001
# statics: [('average_q', 0.19856171), ('average_loss', 27.215711429268122), ('cumulative_steps', 10850), ('n_updates', 4426), ('rlen', 10850)]
# =============
# episode: 217, reward: 48.00000000000002
# statics: [('average_q', 0.20303814), ('average_loss', 27.723874382898213), ('cumulative_steps', 10900), ('n_updates', 4451), ('rlen', 10900)]
# =============
# episode: 218, reward: 97.99999999999993
# statics: [('average_q', 0.20227955), ('average_loss', 27.23556075498462), ('cumulative_steps', 10950), ('n_updates', 4476), ('rlen', 10950)]
# =============
# episode: 219, reward: 48.00000000000003
# statics: [('average_q', 0.20268966), ('average_loss', 28.726883975714443), ('cumulative_steps', 11000), ('n_updates', 4501), ('rlen', 11000)]
# =============
# episode: 220, reward: -2.000000000000001
# statics: [('average_q', 0.19221836), ('average_loss', 25.754984515830873), ('cumulative_steps', 11050), ('n_updates', 4526), ('rlen', 11050)]
# =============
# episode: 221, reward: 97.99999999999989
# statics: [('average_q', 0.20936239), ('average_loss', 30.67284715488553), ('cumulative_steps', 11100), ('n_updates', 4551), ('rlen', 11100)]
# =============
# episode: 222, reward: 97.99999999999999
# statics: [('average_q', 0.21078573), ('average_loss', 37.058451525047424), ('cumulative_steps', 11150), ('n_updates', 4576), ('rlen', 11150)]
# =============
# episode: 223, reward: -2.000000000000001
# statics: [('average_q', 0.20598969), ('average_loss', 35.571998587995765), ('cumulative_steps', 11200), ('n_updates', 4601), ('rlen', 11200)]
# =============
# episode: 224, reward: -2.000000000000001
# statics: [('average_q', 0.19915266), ('average_loss', 41.48846124403179), ('cumulative_steps', 11250), ('n_updates', 4626), ('rlen', 11250)]
# =============
# episode: 225, reward: -2.000000000000001
# statics: [('average_q', 0.19407229), ('average_loss', 35.581710024774075), ('cumulative_steps', 11300), ('n_updates', 4651), ('rlen', 11300)]
# =============
# episode: 226, reward: 97.99999999999997
# statics: [('average_q', 0.18547878), ('average_loss', 27.71841694235802), ('cumulative_steps', 11350), ('n_updates', 4676), ('rlen', 11350)]
# =============
# episode: 227, reward: 48.000000000000014
# statics: [('average_q', 0.20518151), ('average_loss', 28.701945139318706), ('cumulative_steps', 11400), ('n_updates', 4701), ('rlen', 11400)]
# =============
# episode: 228, reward: 48.000000000000036
# statics: [('average_q', 0.2097905), ('average_loss', 28.21992794729769), ('cumulative_steps', 11450), ('n_updates', 4726), ('rlen', 11450)]
# =============
# episode: 229, reward: 48.00000000000001
# statics: [('average_q', 0.1943335), ('average_loss', 27.225007949024437), ('cumulative_steps', 11500), ('n_updates', 4751), ('rlen', 11500)]
# =============
# episode: 230, reward: 98.00000000000001
# statics: [('average_q', 0.20901643), ('average_loss', 31.14825116507709), ('cumulative_steps', 11550), ('n_updates', 4776), ('rlen', 11550)]
# =============
# episode: 231, reward: 98.0
# statics: [('average_q', 0.22117227), ('average_loss', 34.554885593429205), ('cumulative_steps', 11600), ('n_updates', 4801), ('rlen', 11600)]
# =============
# episode: 232, reward: 48.0
# statics: [('average_q', 0.1960397), ('average_loss', 30.125856129825117), ('cumulative_steps', 11650), ('n_updates', 4826), ('rlen', 11650)]
# =============
# episode: 233, reward: 48.000000000000036
# statics: [('average_q', 0.1973481), ('average_loss', 32.10235341783613), ('cumulative_steps', 11700), ('n_updates', 4851), ('rlen', 11700)]
# =============
# episode: 234, reward: -2.000000000000001
# statics: [('average_q', 0.20297797), ('average_loss', 31.60578292865306), ('cumulative_steps', 11750), ('n_updates', 4876), ('rlen', 11750)]
# =============
# episode: 235, reward: 48.00000000000002
# statics: [('average_q', 0.20392668), ('average_loss', 28.191190538592636), ('cumulative_steps', 11800), ('n_updates', 4901), ('rlen', 11800)]
# =============
# episode: 236, reward: -2.000000000000001
# statics: [('average_q', 0.19907862), ('average_loss', 30.155386841483413), ('cumulative_steps', 11850), ('n_updates', 4926), ('rlen', 11850)]
# =============
# episode: 237, reward: -2.000000000000001
# statics: [('average_q', 0.20804276), ('average_loss', 33.10760603532195), ('cumulative_steps', 11900), ('n_updates', 4951), ('rlen', 11900)]
# =============
# episode: 238, reward: 98.00000000000001
# statics: [('average_q', 0.189798), ('average_loss', 29.67438243061304), ('cumulative_steps', 11950), ('n_updates', 4976), ('rlen', 11950)]
# =============
# episode: 239, reward: 48.00000000000001
# statics: [('average_q', 0.20039648), ('average_loss', 29.68107494302094), ('cumulative_steps', 12000), ('n_updates', 5001), ('rlen', 12000)]
# =============
# episode: 240, reward: -2.000000000000001
# statics: [('average_q', 0.19545154), ('average_loss', 29.662884188070894), ('cumulative_steps', 12050), ('n_updates', 5026), ('rlen', 12050)]
# =============
# episode: 241, reward: 48.000000000000036
# statics: [('average_q', 0.19982919), ('average_loss', 26.712907646372916), ('cumulative_steps', 12100), ('n_updates', 5051), ('rlen', 12100)]
# =============
# episode: 242, reward: 48.000000000000014
# statics: [('average_q', 0.1933537), ('average_loss', 28.187535794898867), ('cumulative_steps', 12150), ('n_updates', 5076), ('rlen', 12150)]
# =============
# episode: 243, reward: 98.00000000000001
# statics: [('average_q', 0.19936897), ('average_loss', 25.709898866713047), ('cumulative_steps', 12200), ('n_updates', 5101), ('rlen', 12200)]
# =============
# episode: 244, reward: -2.000000000000001
# statics: [('average_q', 0.20410357), ('average_loss', 28.67280246578157), ('cumulative_steps', 12250), ('n_updates', 5126), ('rlen', 12250)]
# =============
# episode: 245, reward: -2.000000000000001
# statics: [('average_q', 0.20022565), ('average_loss', 30.129987231194974), ('cumulative_steps', 12300), ('n_updates', 5151), ('rlen', 12300)]
# =============
# episode: 246, reward: 48.00000000000004
# statics: [('average_q', 0.20861368), ('average_loss', 32.56904753115028), ('cumulative_steps', 12350), ('n_updates', 5176), ('rlen', 12350)]
# =============
# episode: 247, reward: 48.00000000000003
# statics: [('average_q', 0.19676957), ('average_loss', 32.57196572747082), ('cumulative_steps', 12400), ('n_updates', 5201), ('rlen', 12400)]
# =============
# episode: 248, reward: -2.000000000000001
# statics: [('average_q', 0.20533048), ('average_loss', 32.090052578412), ('cumulative_steps', 12450), ('n_updates', 5226), ('rlen', 12450)]
# =============
# episode: 249, reward: 48.000000000000036
# statics: [('average_q', 0.20389654), ('average_loss', 32.10706589002162), ('cumulative_steps', 12500), ('n_updates', 5251), ('rlen', 12500)]
# =============
# episode: 250, reward: 48.000000000000036
# statics: [('average_q', 0.19763122), ('average_loss', 29.66216535601765), ('cumulative_steps', 12550), ('n_updates', 5276), ('rlen', 12550)]
# =============
# episode: 251, reward: 48.000000000000036
# ...
# =============
# episode: 1919, reward: 147.99999999999997
# statics: [('average_q', 0.50152063), ('average_loss', 35.320549101531505), ('cumulative_steps', 96000), ('n_updates', 47001), ('rlen', 96000)]
# =============
# episode: 1920, reward: -2.000000000000001
# statics: [('average_q', 0.5395712), ('average_loss', 37.09949439466), ('cumulative_steps', 96050), ('n_updates', 47026), ('rlen', 96050)]
# =============
# episode: 1921, reward: 48.000000000000014
# statics: [('average_q', 0.5562304), ('average_loss', 41.95986150473356), ('cumulative_steps', 96100), ('n_updates', 47051), ('rlen', 96100)]
# =============
# episode: 1922, reward: 48.00000000000003
# statics: [('average_q', 0.47082898), ('average_loss', 37.953463006913665), ('cumulative_steps', 96150), ('n_updates', 47076), ('rlen', 96150)]
# =============
# episode: 1923, reward: 97.99999999999987
# statics: [('average_q', 0.4980209), ('average_loss', 37.68687379986048), ('cumulative_steps', 96200), ('n_updates', 47101), ('rlen', 96200)]
# =============
# episode: 1924, reward: 48.00000000000002
# statics: [('average_q', 0.49117565), ('average_loss', 32.834811685681345), ('cumulative_steps', 96250), ('n_updates', 47126), ('rlen', 96250)]
# =============
# episode: 1925, reward: 98.0
# statics: [('average_q', 0.5027346), ('average_loss', 30.783834055662155), ('cumulative_steps', 96300), ('n_updates', 47151), ('rlen', 96300)]
# =============
# episode: 1926, reward: 48.000000000000036
# statics: [('average_q', 0.48639873), ('average_loss', 32.23672069311142), ('cumulative_steps', 96350), ('n_updates', 47176), ('rlen', 96350)]
# =============
# episode: 1927, reward: 48.000000000000014
# statics: [('average_q', 0.5776575), ('average_loss', 33.92235361754894), ('cumulative_steps', 96400), ('n_updates', 47201), ('rlen', 96400)]
# =============
# episode: 1928, reward: 48.00000000000003
# statics: [('average_q', 0.5700188), ('average_loss', 35.65621627122164), ('cumulative_steps', 96450), ('n_updates', 47226), ('rlen', 96450)]
# =============
# episode: 1929, reward: 97.99999999999986
# statics: [('average_q', 0.46638352), ('average_loss', 33.31266653180123), ('cumulative_steps', 96500), ('n_updates', 47251), ('rlen', 96500)]
# =============
# episode: 1930, reward: 48.000000000000036
# statics: [('average_q', 0.48342448), ('average_loss', 33.192297335267064), ('cumulative_steps', 96550), ('n_updates', 47276), ('rlen', 96550)]
# =============
# episode: 1931, reward: -2.000000000000001
# statics: [('average_q', 0.5331302), ('average_loss', 32.01686388015747), ('cumulative_steps', 96600), ('n_updates', 47301), ('rlen', 96600)]
# =============
# episode: 1932, reward: 97.99999999999987
# statics: [('average_q', 0.5064764), ('average_loss', 30.001172618865965), ('cumulative_steps', 96650), ('n_updates', 47326), ('rlen', 96650)]
# =============
# episode: 1933, reward: -2.000000000000001
# statics: [('average_q', 0.52997357), ('average_loss', 30.900696099996566), ('cumulative_steps', 96700), ('n_updates', 47351), ('rlen', 96700)]
# =============
# episode: 1934, reward: 97.99999999999999
# statics: [('average_q', 0.53462774), ('average_loss', 32.5132319933176), ('cumulative_steps', 96750), ('n_updates', 47376), ('rlen', 96750)]
# =============
# episode: 1935, reward: -2.000000000000001
# statics: [('average_q', 0.5110238), ('average_loss', 29.824785191714763), ('cumulative_steps', 96800), ('n_updates', 47401), ('rlen', 96800)]
# =============
# episode: 1936, reward: -2.000000000000001
# statics: [('average_q', 0.50106597), ('average_loss', 32.137648883163926), ('cumulative_steps', 96850), ('n_updates', 47426), ('rlen', 96850)]
# =============
# episode: 1937, reward: -2.000000000000001
# statics: [('average_q', 0.5869325), ('average_loss', 32.08724111586809), ('cumulative_steps', 96900), ('n_updates', 47451), ('rlen', 96900)]
# =============
# episode: 1938, reward: 48.00000000000003
# statics: [('average_q', 0.52046335), ('average_loss', 31.830232422947883), ('cumulative_steps', 96950), ('n_updates', 47476), ('rlen', 96950)]
# =============
# episode: 1939, reward: -2.000000000000001
# statics: [('average_q', 0.59667367), ('average_loss', 35.2006889501214), ('cumulative_steps', 97000), ('n_updates', 47501), ('rlen', 97000)]
# =============
# episode: 1940, reward: 48.00000000000002
# statics: [('average_q', 0.5513544), ('average_loss', 32.77786996632815), ('cumulative_steps', 97050), ('n_updates', 47526), ('rlen', 97050)]
# =============
# episode: 1941, reward: 48.0
# statics: [('average_q', 0.47772515), ('average_loss', 30.698106391131876), ('cumulative_steps', 97100), ('n_updates', 47551), ('rlen', 97100)]
# =============
# episode: 1942, reward: 98.00000000000001
# statics: [('average_q', 0.52037084), ('average_loss', 27.308472506403923), ('cumulative_steps', 97150), ('n_updates', 47576), ('rlen', 97150)]
# =============
# episode: 1943, reward: -2.000000000000001
# statics: [('average_q', 0.5038622), ('average_loss', 26.01196231931448), ('cumulative_steps', 97200), ('n_updates', 47601), ('rlen', 97200)]
# =============
# episode: 1944, reward: 48.000000000000036
# statics: [('average_q', 0.5462705), ('average_loss', 28.30644994825125), ('cumulative_steps', 97250), ('n_updates', 47626), ('rlen', 97250)]
# =============
# episode: 1945, reward: 147.99999999999997
# statics: [('average_q', 0.51915026), ('average_loss', 29.45417672753334), ('cumulative_steps', 97300), ('n_updates', 47651), ('rlen', 97300)]
# =============
# episode: 1946, reward: 148.00000000000017
# statics: [('average_q', 0.52354914), ('average_loss', 30.143842116892337), ('cumulative_steps', 97350), ('n_updates', 47676), ('rlen', 97350)]
# =============
# episode: 1947, reward: 97.99999999999996
# statics: [('average_q', 0.5067543), ('average_loss', 30.423746735453605), ('cumulative_steps', 97400), ('n_updates', 47701), ('rlen', 97400)]
# =============
# episode: 1948, reward: 48.0
# statics: [('average_q', 0.52819926), ('average_loss', 30.308245876431464), ('cumulative_steps', 97450), ('n_updates', 47726), ('rlen', 97450)]
# =============
# episode: 1949, reward: 48.0
# statics: [('average_q', 0.5023378), ('average_loss', 30.412640256881716), ('cumulative_steps', 97500), ('n_updates', 47751), ('rlen', 97500)]
# =============
# episode: 1950, reward: 48.00000000000002
# statics: [('average_q', 0.46743166), ('average_loss', 31.915240296423434), ('cumulative_steps', 97550), ('n_updates', 47776), ('rlen', 97550)]
# =============
# episode: 1951, reward: 148.0
# statics: [('average_q', 0.52209634), ('average_loss', 28.243368944227697), ('cumulative_steps', 97600), ('n_updates', 47801), ('rlen', 97600)]
# =============
# episode: 1952, reward: 48.00000000000003
# statics: [('average_q', 0.49527258), ('average_loss', 30.90044493228197), ('cumulative_steps', 97650), ('n_updates', 47826), ('rlen', 97650)]
# =============
# episode: 1953, reward: 48.00000000000003
# statics: [('average_q', 0.47613767), ('average_loss', 32.74404597938061), ('cumulative_steps', 97700), ('n_updates', 47851), ('rlen', 97700)]
# =============
# episode: 1954, reward: 147.99999999999991
# statics: [('average_q', 0.47977), ('average_loss', 32.05086650252342), ('cumulative_steps', 97750), ('n_updates', 47876), ('rlen', 97750)]
# =============
# episode: 1955, reward: -2.000000000000001
# statics: [('average_q', 0.4830965), ('average_loss', 35.05073383897543), ('cumulative_steps', 97800), ('n_updates', 47901), ('rlen', 97800)]
# =============
# episode: 1956, reward: 48.000000000000036
# statics: [('average_q', 0.5155098), ('average_loss', 30.26177468150854), ('cumulative_steps', 97850), ('n_updates', 47926), ('rlen', 97850)]
# =============
# episode: 1957, reward: 97.99999999999999
# statics: [('average_q', 0.5527014), ('average_loss', 30.864091511964798), ('cumulative_steps', 97900), ('n_updates', 47951), ('rlen', 97900)]
# =============
# episode: 1958, reward: 148.0
# statics: [('average_q', 0.48856866), ('average_loss', 31.879974757432937), ('cumulative_steps', 97950), ('n_updates', 47976), ('rlen', 97950)]
# =============
# episode: 1959, reward: -2.000000000000001
# statics: [('average_q', 0.5280605), ('average_loss', 31.01512746632099), ('cumulative_steps', 98000), ('n_updates', 48001), ('rlen', 98000)]
# =============
# episode: 1960, reward: 97.99999999999991
# statics: [('average_q', 0.5342528), ('average_loss', 35.60433446764946), ('cumulative_steps', 98050), ('n_updates', 48026), ('rlen', 98050)]
# =============
# episode: 1961, reward: 48.00000000000003
# statics: [('average_q', 0.49810988), ('average_loss', 35.46293356567621), ('cumulative_steps', 98100), ('n_updates', 48051), ('rlen', 98100)]
# =============
# episode: 1962, reward: 48.000000000000036
# statics: [('average_q', 0.51100916), ('average_loss', 33.48480745226145), ('cumulative_steps', 98150), ('n_updates', 48076), ('rlen', 98150)]
# =============
# episode: 1963, reward: 48.0
# statics: [('average_q', 0.550742), ('average_loss', 34.75613527834415), ('cumulative_steps', 98200), ('n_updates', 48101), ('rlen', 98200)]
# =============
# episode: 1964, reward: -2.000000000000001
# statics: [('average_q', 0.4954814), ('average_loss', 33.041719102859496), ('cumulative_steps', 98250), ('n_updates', 48126), ('rlen', 98250)]
# =============
# episode: 1965, reward: -2.000000000000001
# statics: [('average_q', 0.5027934), ('average_loss', 33.422598596215245), ('cumulative_steps', 98300), ('n_updates', 48151), ('rlen', 98300)]
# =============
# episode: 1966, reward: 48.00000000000002
# statics: [('average_q', 0.5266024), ('average_loss', 33.72008507788181), ('cumulative_steps', 98350), ('n_updates', 48176), ('rlen', 98350)]
# =============
# episode: 1967, reward: -2.000000000000001
# statics: [('average_q', 0.47996917), ('average_loss', 34.46461544394493), ('cumulative_steps', 98400), ('n_updates', 48201), ('rlen', 98400)]
# =============
# episode: 1968, reward: 147.99999999999994
# statics: [('average_q', 0.5591889), ('average_loss', 32.11060078799724), ('cumulative_steps', 98450), ('n_updates', 48226), ('rlen', 98450)]
# =============
# episode: 1969, reward: 97.99999999999987
# statics: [('average_q', 0.5431998), ('average_loss', 29.612125687599182), ('cumulative_steps', 98500), ('n_updates', 48251), ('rlen', 98500)]
# =============
# episode: 1970, reward: -2.000000000000001
# statics: [('average_q', 0.64194167), ('average_loss', 28.642050572037697), ('cumulative_steps', 98550), ('n_updates', 48276), ('rlen', 98550)]
# =============
# episode: 1971, reward: 97.99999999999983
# statics: [('average_q', 0.56199646), ('average_loss', 29.116436775922775), ('cumulative_steps', 98600), ('n_updates', 48301), ('rlen', 98600)]
# =============
# episode: 1972, reward: 48.000000000000036
# statics: [('average_q', 0.5357123), ('average_loss', 31.016465172171593), ('cumulative_steps', 98650), ('n_updates', 48326), ('rlen', 98650)]
# =============
# episode: 1973, reward: -2.000000000000001
# statics: [('average_q', 0.5241889), ('average_loss', 30.60273247003555), ('cumulative_steps', 98700), ('n_updates', 48351), ('rlen', 98700)]
# =============
# episode: 1974, reward: -2.000000000000001
# statics: [('average_q', 0.510609), ('average_loss', 37.07635310083628), ('cumulative_steps', 98750), ('n_updates', 48376), ('rlen', 98750)]
# =============
# episode: 1975, reward: 48.00000000000002
# statics: [('average_q', 0.5529777), ('average_loss', 37.96251358836889), ('cumulative_steps', 98800), ('n_updates', 48401), ('rlen', 98800)]
# =============
# episode: 1976, reward: 98.00000000000003
# statics: [('average_q', 0.56096643), ('average_loss', 42.04861993461847), ('cumulative_steps', 98850), ('n_updates', 48426), ('rlen', 98850)]
# =============
# episode: 1977, reward: -2.000000000000001
# statics: [('average_q', 0.48811066), ('average_loss', 42.04790339499712), ('cumulative_steps', 98900), ('n_updates', 48451), ('rlen', 98900)]
# =============
# episode: 1978, reward: 48.000000000000036
# statics: [('average_q', 0.46068847), ('average_loss', 38.40901082873344), ('cumulative_steps', 98950), ('n_updates', 48476), ('rlen', 98950)]
# =============
# episode: 1979, reward: 98.0
# statics: [('average_q', 0.48434344), ('average_loss', 34.71198368638754), ('cumulative_steps', 99000), ('n_updates', 48501), ('rlen', 99000)]
# =============
# episode: 1980, reward: 48.00000000000003
# statics: [('average_q', 0.49115843), ('average_loss', 27.15874379277229), ('cumulative_steps', 99050), ('n_updates', 48526), ('rlen', 99050)]
# =============
# episode: 1981, reward: -2.000000000000001
# statics: [('average_q', 0.55670464), ('average_loss', 30.574822056889534), ('cumulative_steps', 99100), ('n_updates', 48551), ('rlen', 99100)]
# =============
# episode: 1982, reward: -2.000000000000001
# statics: [('average_q', 0.5488077), ('average_loss', 31.308729568123816), ('cumulative_steps', 99150), ('n_updates', 48576), ('rlen', 99150)]
# =============
# episode: 1983, reward: -2.000000000000001
# statics: [('average_q', 0.45966825), ('average_loss', 30.449121468961238), ('cumulative_steps', 99200), ('n_updates', 48601), ('rlen', 99200)]
# =============
# episode: 1984, reward: -2.000000000000001
# statics: [('average_q', 0.5411074), ('average_loss', 34.241127622127536), ('cumulative_steps', 99250), ('n_updates', 48626), ('rlen', 99250)]
# =============
# episode: 1985, reward: -2.000000000000001
# statics: [('average_q', 0.56086785), ('average_loss', 29.141868538856507), ('cumulative_steps', 99300), ('n_updates', 48651), ('rlen', 99300)]
# =============
# episode: 1986, reward: 48.00000000000003
# statics: [('average_q', 0.6265979), ('average_loss', 31.30740698546171), ('cumulative_steps', 99350), ('n_updates', 48676), ('rlen', 99350)]
# =============
# episode: 1987, reward: -2.000000000000001
# statics: [('average_q', 0.4962188), ('average_loss', 32.715885991752145), ('cumulative_steps', 99400), ('n_updates', 48701), ('rlen', 99400)]
# =============
# episode: 1988, reward: -2.000000000000001
# statics: [('average_q', 0.5773225), ('average_loss', 33.41799242943525), ('cumulative_steps', 99450), ('n_updates', 48726), ('rlen', 99450)]
# =============
# episode: 1989, reward: -2.000000000000001
# statics: [('average_q', 0.52399457), ('average_loss', 37.672800650894644), ('cumulative_steps', 99500), ('n_updates', 48751), ('rlen', 99500)]
# =============
# episode: 1990, reward: 48.00000000000002
# statics: [('average_q', 0.6128887), ('average_loss', 35.44147883832455), ('cumulative_steps', 99550), ('n_updates', 48776), ('rlen', 99550)]
# =============
# episode: 1991, reward: 48.00000000000001
# statics: [('average_q', 0.48345256), ('average_loss', 35.241197368204595), ('cumulative_steps', 99600), ('n_updates', 48801), ('rlen', 99600)]
# =============
# episode: 1992, reward: -2.000000000000001
# statics: [('average_q', 0.5466474), ('average_loss', 35.19317821055651), ('cumulative_steps', 99650), ('n_updates', 48826), ('rlen', 99650)]
# =============
# episode: 1993, reward: 48.00000000000001
# statics: [('average_q', 0.5411738), ('average_loss', 33.093374501168725), ('cumulative_steps', 99700), ('n_updates', 48851), ('rlen', 99700)]
# =============
# episode: 1994, reward: -2.000000000000001
# statics: [('average_q', 0.5163087), ('average_loss', 30.327149131596087), ('cumulative_steps', 99750), ('n_updates', 48876), ('rlen', 99750)]
# =============
# episode: 1995, reward: -2.000000000000001
# statics: [('average_q', 0.471173), ('average_loss', 28.180591809153558), ('cumulative_steps', 99800), ('n_updates', 48901), ('rlen', 99800)]
# =============
# episode: 1996, reward: 48.000000000000036
# statics: [('average_q', 0.5460482), ('average_loss', 28.199448595643045), ('cumulative_steps', 99850), ('n_updates', 48926), ('rlen', 99850)]
# =============
# episode: 1997, reward: 48.00000000000004
# statics: [('average_q', 0.53771746), ('average_loss', 27.273368189930917), ('cumulative_steps', 99900), ('n_updates', 48951), ('rlen', 99900)]
# =============
# episode: 1998, reward: -2.000000000000001
# statics: [('average_q', 0.5313402), ('average_loss', 31.962864933013915), ('cumulative_steps', 99950), ('n_updates', 48976), ('rlen', 99950)]
# =============
# episode: 1999, reward: 48.00000000000003
# statics: [('average_q', 0.5372034), ('average_loss', 33.319970151484014), ('cumulative_steps', 100000), ('n_updates', 49001), ('rlen', 100000)]
# Finished
#
# ====================
# Training Time: 3:19:29.414833
# ====================
